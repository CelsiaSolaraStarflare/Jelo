# %% [markdown]
# # Illinois Excel Data Analysis with Pandas
#
# This notebook demonstrates the analysis of the `Illinois.xlsx` file from the export folder using pandas. Moreover, it considers main types of data that we can infer and investigate from this project.

# %% [markdown]
# ## 1. Import Required Libraries
# Import pandas and any other necessary libraries for data analysis.

# %%
# !cd export
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load the Excel File
# Use pandas' `read_excel` function to load the 'Illinois.xlsx' file into a DataFrame.

# %%
# Load the CSV file
file_path = 'c:/Users/osmon/Desktop/custom_data/export/Illinois.csv'

# Skip the first two rows and use the third row as the header
df = pd.read_csv(file_path, header=2)

# Clean up column names by stripping any extra whitespace
df.columns = df.columns.str.strip()

# Remove the last row if it's problematic (as seen in the file summary)
if df.iloc[-1]['State'] == '98 Special Classification Provisions, Nesoi':
    df = df.iloc[:-1]


df.head()
# Out:
#       State        Commodity       Country    Time Vessel Value ($US)  \
# 0  Illinois  01 Live Animals        Africa  Jul-16              7,185
# 1  Illinois  01 Live Animals        Africa  Feb-20             13,792
# 2  Illinois  01 Live Animals  Asia - South  Jun-18             15,087
# 3  Illinois  01 Live Animals  Asia - Other  Mar-08             12,515
# 4  Illinois  01 Live Animals  Asia - Other  Jul-08             12,135
#
#   Containerized Vessel Total Exports Value ($US) Vessel SWT (kg)  \
# 0                                          7,185               6
# 1                                            NaN             494
# 2                                         15,087           1,422
# 3                                            NaN          19,958
# 4                                            NaN          20,284
#
#   Containerized Vessel Total Exports SWT (kg)
# 0                                           6
# 1                                         NaN
# 2                                       1,422
# 3                                         NaN
# 4                                         NaN

# %%
# Debug: Check file existence and list directory contents
import os

# Print current working directory
print("Current working directory:", os.getcwd())

# Check if file exists
print("File exists:", os.path.exists(file_path))

# List contents of the export directory
export_dir = 'c:/Users/osmon/Desktop/custom_data/export'
print("\nContents of export directory:")
if os.path.exists(export_dir):
    print(os.listdir(export_dir))
else:
    print("Export directory not found")
# Out:
# Current working directory: c:\Users\osmon\Desktop\custom_data
# File exists: True
#
# Contents of export directory:
# ['.DS_Store', 'Arkansas.csv', 'Illinois.csv', 'Iowa.csv', 'Louisiana.csv', 'Minnesota.csv', 'Mississippi.csv', 'Missouri.csv', 'Wisconsin.csv']

# %%
import os
print("File exists:", os.path.exists(file_path))
# Out:
# File exists: True

# %% [markdown]
# ## 3. Explore the DataFrame
# Display the first few rows, check the shape, and inspect column names and data types.

# %%
# Display the first 5 rows
print('First 5 rows:')
display(df.head())

# Shape of the DataFrame
print('Shape:', df.shape)

# Column names
print('Columns:', df.columns.tolist())

# Data types
print('Data types:')
print(df.dtypes)
# Out:
# First 5 rows:
#       State        Commodity       Country    Time  Vessel Value ($US)  \
# 0  Illinois  01 Live Animals        Africa  Jul-16                7185
# 1  Illinois  01 Live Animals        Africa  Feb-20               13792
# 2  Illinois  01 Live Animals  Asia - South  Jun-18               15087
# 3  Illinois  01 Live Animals  Asia - Other  Mar-08               12515
# 4  Illinois  01 Live Animals  Asia - Other  Jul-08               12135
#
#   Containerized Vessel Total Exports Value ($US)  Vessel SWT (kg)  \
# 0                                          7,185              6.0
# 1                                            NaN            494.0
# 2                                         15,087           1422.0
# 3                                            NaN          19958.0
# 4                                            NaN          20284.0
#
#   Containerized Vessel Total Exports SWT (kg)              Region
# 0                                           6  Other/Unclassified
# 1                                         NaN  Other/Unclassified
# 2                                       1,422  Other/Unclassified
# 3                                         NaN  Other/Unclassified
# 4                                         NaN  Other/Unclassified
# Shape: (110711, 9)
# Columns: ['State', 'Commodity', 'Country', 'Time', 'Vessel Value ($US)', 'Containerized Vessel Total Exports Value ($US)', 'Vessel SWT (kg)', 'Containerized Vessel Total Exports SWT (kg)', 'Region']
# Data types:
# State                                              object
# Commodity                                          object
# Country                                            object
# Time                                               object
# Vessel Value ($US)                                  int64
# Containerized Vessel Total Exports Value ($US)     object
# Vessel SWT (kg)                                   float64
# Containerized Vessel Total Exports SWT (kg)        object
# Region                                             object
# dtype: object

# %% [markdown]
# ## 4. Basic Data Analysis with Pandas
# Perform basic analysis such as summary statistics, value counts, and filtering rows.

# %%
# Summary statistics for numeric columns
print('Summary statistics:')
display(df.describe())

# Value counts for the first column (if categorical)
first_col = df.columns[0]
print(f'Value counts for {first_col}:')
display(df[first_col].value_counts())

# Example: Filter rows where the first column equals its first value
first_value = df[first_col].iloc[0]
filtered_df = df[df[first_col] == first_value]
print(f'Rows where {first_col} == {first_value}:')
display(filtered_df.head())
# Out:
# Summary statistics:
#            State                                          Commodity  \
# count     110711                                             110711
# unique         1                                                 97
# top     Illinois  84 Nuclear Reactors, Boilers, Machinery Etc.; ...
# freq      110711                                               1878
#
#              Country    Time Vessel Value ($US)  \
# count         110711  110711             110711
# unique            10     209             100259
# top     Asia - Other  Mar-17             10,000
# freq           16835     563                 87
#
#        Containerized Vessel Total Exports Value ($US) Vessel SWT (kg)  \
# count                                          104171          110709
# unique                                          93598           81052
# top                                            10,000               1
# freq                                               67              71
#
#        Containerized Vessel Total Exports SWT (kg)
# count                                       104170
# unique                                       75321
# top                                          1,000
# freq                                            71
# Value counts for State:
# State
# Illinois    110711
# Name: count, dtype: int64
# Rows where State == Illinois:
#       State        Commodity       Country    Time Vessel Value ($US)  \
# 0  Illinois  01 Live Animals        Africa  Jul-16              7,185
# 1  Illinois  01 Live Animals        Africa  Feb-20             13,792
# 2  Illinois  01 Live Animals  Asia - South  Jun-18             15,087
# 3  Illinois  01 Live Animals  Asia - Other  Mar-08             12,515
# 4  Illinois  01 Live Animals  Asia - Other  Jul-08             12,135
#
#   Containerized Vessel Total Exports Value ($US) Vessel SWT (kg)  \
# 0                                          7,185               6
# 1                                            NaN             494
# 2                                         15,087           1,422
# 3                                            NaN          19,958
# 4                                            NaN          20,284
#
#   Containerized Vessel Total Exports SWT (kg)
# 0                                           6
# 1                                         NaN
# 2                                       1,422
# 3                                         NaN
# 4                                         NaN

# %% [markdown]
# ## 5. Analyze Commodities and Export Amounts
# Summarize the unique commodities and their total export amounts. Visualize the top commodities.
#
# ## 6. Modeling Ideas
# Discuss possible predictive models and next steps for export data analysis.

# %%
# Replace 'Commodity' and 'ExportAmount' with actual column names if different
commodity_col = 'Commodity'  # This is correct
amount_col = 'Vessel Value ($US)'  # Changed to the actual column name

# Convert the amount column to a numeric type, removing commas
df[amount_col] = pd.to_numeric(df[amount_col].str.replace(',', '', regex=False), errors='coerce')


# List unique commodities
print('Unique commodities:')
print(df[commodity_col].unique())

# Total export amount by commodity
top_commodities = df.groupby(commodity_col)[amount_col].sum().sort_values(ascending=False)
print('Top commodities by total export amount:')
print(top_commodities.head(10))

# Plot top 10 commodities
import matplotlib.pyplot as plt
top_commodities.head(10).plot(kind='bar', figsize=(10,5), title='Top 10 Commodities by Export Amount')
plt.ylabel('Export Amount ($US)')
plt.xlabel('Commodity')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 6
#       3 amount_col = 'Vessel Value ($US)'  # Changed to the actual column name
#       5 # Convert the amount column to a numeric type, removing commas
# ----> 6 df[amount_col] = pd.to_numeric(df[amount_col].str.replace(',', '', regex=False), errors='coerce')
#       9 # List unique commodities
#      10 print('Unique commodities:')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %% [markdown]
# ## 7. Analyze Commodity Quantities and Rankings
#
# In this section, we will calculate the total quantity of each commodity and rank them based on their quantities.

# %%
# Replace 'Commodity' and 'Quantity' with actual column names if different
quantity_col = 'Vessel SWT (kg)'  # Changed to the actual column name for weight/quantity

# Convert the quantity column to numeric, removing commas if any
df[quantity_col] = pd.to_numeric(df[quantity_col].str.replace(',', '', regex=False), errors='coerce')

# Total quantity by commodity
total_quantities = df.groupby(commodity_col)[quantity_col].sum().sort_values(ascending=False)
print('Top commodities by total quantity (weight in kg):')
print(total_quantities.head(10))

# Plot top 10 commodities by quantity
total_quantities.head(10).plot(kind='bar', figsize=(10,5), title='Top 10 Commodities by Weight (kg)')
plt.ylabel('Total Weight (kg)')
plt.xlabel('Commodity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Top commodities by total quantity (weight in kg):
# Commodity
# 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc    5.818376e+10
# 23 Food Industry Residues & Waste; Prep Animal Feed      5.705448e+10
# 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax    5.208898e+10
# 10 Cereals                                               3.525344e+10
# 47 Wood Pulp Etc; Recovd (waste & Scrap) ppr & pprbd     1.421505e+10
# 87 Vehicles, Except Railway Or Tramway, And Parts Etc    5.383505e+09
# 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts      5.181109e+09
# 39 Plastics And Articles Thereof                         4.853657e+09
# 72 Iron And Steel                                        4.291991e+09
# 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd    4.170289e+09
# Name: Vessel SWT (kg), dtype: float64

# %% [markdown]
# ## 8. Analyze Export Destinations (Countries/Regions)
#
# In this section, we will analyze the countries and regions that Illinois exports goods to, including total export values and quantities by destination.

# %%
# Analyze export destinations by country
country_col = 'Country'

# Total export value by country
export_value_by_country = df.groupby(country_col)[amount_col].sum().sort_values(ascending=False)
print('Top export destinations by total value ($US):')
print(export_value_by_country.head(15))

# Total export weight by country
export_weight_by_country = df.groupby(country_col)[quantity_col].sum().sort_values(ascending=False)
print('\nTop export destinations by total weight (kg):')
print(export_weight_by_country.head(15))

# Create visualizations
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot top 10 countries by export value
export_value_by_country.head(10).plot(kind='bar', ax=ax1, color='skyblue')
ax1.set_title('Top 10 Export Destinations by Value')
ax1.set_ylabel('Export Value ($US)')
ax1.set_xlabel('Country')
ax1.tick_params(axis='x', rotation=45)

# Plot top 10 countries by export weight
export_weight_by_country.head(10).plot(kind='bar', ax=ax2, color='lightcoral')
ax2.set_title('Top 10 Export Destinations by Weight')
ax2.set_ylabel('Export Weight (kg)')
ax2.set_xlabel('Country')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# Top export destinations by total value ($US):
# Country
# Asia - Other                     125247626417
# Europe                            78444495142
# South America                     55822129515
# Australia and Oceania             44054058030
# Africa                            18647095212
# Asia Near East                    16618838030
# Central America and Caribbean     12997599216
# Asia - South                      12576757498
# North America                      5344753408
# Unidentified Countries                2070007
# Name: Vessel Value ($US), dtype: int64
#
# Top export destinations by total weight (kg):
# Country
# Asia - Other                     1.546188e+11
# Europe                           5.193529e+10
# South America                    1.507994e+10
# North America                    1.500410e+10
# Asia - South                     1.477684e+10
# Africa                           1.033688e+10
# Central America and Caribbean    8.595107e+09
# Asia Near East                   4.853625e+09
# Australia and Oceania            4.373764e+09
# Unidentified Countries           5.442880e+06
# Name: Vessel SWT (kg), dtype: float64

# %%
# Detailed country analysis
print('=== EXPORT DESTINATION ANALYSIS ===\n')

# Number of unique countries
unique_countries = df[country_col].nunique()
print(f'Illinois exports to {unique_countries} different countries/regions')

# Top 5 countries with detailed breakdown
print('\n--- TOP 5 EXPORT DESTINATIONS (Detailed) ---')
top_5_countries = export_value_by_country.head(5).index

for country in top_5_countries:
    country_data = df[df[country_col] == country]
    total_value = export_value_by_country[country]
    total_weight = export_weight_by_country[country]
    avg_value_per_kg = total_value / total_weight if total_weight > 0 else 0
    num_commodities = country_data[commodity_col].nunique()
    
    print(f'\n{country}:')
    print(f'  • Total Export Value: ${total_value:,.0f}')
    print(f'  • Total Export Weight: {total_weight:,.0f} kg')
    print(f'  • Average Value per kg: ${avg_value_per_kg:.2f}')
    print(f'  • Number of Different Commodities: {num_commodities}')
    
    # Top 3 commodities for this country
    top_commodities_country = country_data.groupby(commodity_col)[amount_col].sum().sort_values(ascending=False).head(3)
    print(f'  • Top 3 Commodities:')
    for i, (commodity, value) in enumerate(top_commodities_country.items(), 1):
        print(f'    {i}. {commodity}: ${value:,.0f}')

# Regional analysis (basic grouping)
print('\n--- REGIONAL ANALYSIS ---')

# Create a simple regional mapping (you can expand this)
regional_mapping = {
    'Canada': 'North America',
    'Mexico': 'North America',
    'China': 'Asia',
    'Japan': 'Asia',
    'South Korea': 'Asia',
    'Germany': 'Europe',
    'United Kingdom': 'Europe',
    'France': 'Europe',
    'Netherlands': 'Europe',
    'Brazil': 'South America',
    'Argentina': 'South America',
    'Australia': 'Oceania'
}

# Add region column
df['Region'] = df[country_col].map(regional_mapping).fillna('Other/Unclassified')

# Regional export analysis
regional_exports = df.groupby('Region')[amount_col].sum().sort_values(ascending=False)
print('Export Value by Region:')
for region, value in regional_exports.items():
    percentage = (value / df[amount_col].sum()) * 100
    print(f'  {region}: ${value:,.0f} ({percentage:.1f}% of total)')
# Out:
# === EXPORT DESTINATION ANALYSIS ===
#
# Illinois exports to 10 different countries/regions
#
# --- TOP 5 EXPORT DESTINATIONS (Detailed) ---
#
# Asia - Other:
#   • Total Export Value: $125,247,626,417
#   • Total Export Weight: 154,618,814,315 kg
#   • Average Value per kg: $0.81
#   • Number of Different Commodities: 97
#   • Top 3 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $23,700,965,695
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $16,985,522,352
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $12,332,218,480
#
# Europe:
#   • Total Export Value: $78,444,495,142
#   • Total Export Weight: 51,935,288,580 kg
#   • Average Value per kg: $1.51
#   • Number of Different Commodities: 97
#   • Top 3 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $16,202,606,953
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $11,474,998,912
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $6,896,398,849
#
# South America:
#   • Total Export Value: $55,822,129,515
#   • Total Export Weight: 15,079,939,665 kg
#   • Average Value per kg: $3.70
#   • Number of Different Commodities: 97
#   • Top 3 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $17,111,044,380
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $14,537,642,228
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $3,342,667,058
#
# Australia and Oceania:
#   • Total Export Value: $44,054,058,030
#   • Total Export Weight: 4,373,764,488 kg
#   • Average Value per kg: $10.07
#   • Number of Different Commodities: 96
#   • Top 3 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $17,406,972,073
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $14,283,908,661
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $1,598,963,470
#
# Africa:
#   • Total Export Value: $18,647,095,212
#   • Total Export Weight: 10,336,881,044 kg
#   • Average Value per kg: $1.80
#   • Number of Different Commodities: 95
#   • Top 3 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $6,959,281,046
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $4,982,372,351
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $820,634,800
#
# --- REGIONAL ANALYSIS ---
# Export Value by Region:
#   Other/Unclassified: $369,755,422,475 (100.0% of total)

# %% [markdown]
# ## 9. Temporal Analysis: Exports by Time of Year
#
# In this section, we will analyze how Illinois exports vary throughout the year, identifying seasonal patterns and trends in commodity exports.

# %%
# Temporal analysis of exports
time_col = 'Time'

# First, let's examine the time column format
print('Sample time values:')
print(df[time_col].head(10))
print(f'\nUnique time periods: {df[time_col].nunique()}')
print('\nAll time periods:')
print(sorted(df[time_col].unique()))

# Convert time column to datetime if possible, or extract month/year information
try:
    # Try to convert to datetime
    df['DateTime'] = pd.to_datetime(df[time_col])
    df['Year'] = df['DateTime'].dt.year
    df['Month'] = df['DateTime'].dt.month
    df['MonthName'] = df['DateTime'].dt.month_name()
    datetime_conversion_success = True
    print('\nSuccessfully converted time column to datetime format')
except:
    # If direct conversion fails, try to extract patterns
    datetime_conversion_success = False
    print('\nDirect datetime conversion failed, analyzing time format...')
    
    # Try to extract year and month from common formats
    time_str = str(df[time_col].iloc[0])
    print(f'Sample time format: {time_str}')
# Out:
# Sample time values:
# 0    Jul-16
# 1    Feb-20
# 2    Jun-18
# 3    Mar-08
# 4    Jul-08
# 5    Sep-09
# 6    Dec-11
# 7    Jan-12
# 8    Mar-19
# 9    Apr-22
# Name: Time, dtype: object
#
# Unique time periods: 209
#
# All time periods:
# ['Apr-08', 'Apr-09', 'Apr-10', 'Apr-11', 'Apr-12', 'Apr-13', 'Apr-14', 'Apr-15', 'Apr-16', 'Apr-17', 'Apr-18', 'Apr-19', 'Apr-20', 'Apr-21', 'Apr-22', 'Apr-23', 'Apr-24', 'Apr-25', 'Aug-08', 'Aug-09', 'Aug-10', 'Aug-11', 'Aug-12', 'Aug-13', 'Aug-14', 'Aug-15', 'Aug-16', 'Aug-17', 'Aug-18', 'Aug-19', 'Aug-20', 'Aug-21', 'Aug-22', 'Aug-23', 'Aug-24', 'Dec-08', 'Dec-09', 'Dec-10', 'Dec-11', 'Dec-12', 'Dec-13', 'Dec-14', 'Dec-15', 'Dec-16', 'Dec-17', 'Dec-18', 'Dec-19', 'Dec-20', 'Dec-21', 'Dec-22', 'Dec-23', 'Dec-24', 'Feb-08', 'Feb-09', 'Feb-10', 'Feb-11', 'Feb-12', 'Feb-13', 'Feb-14', 'Feb-15', 'Feb-16', 'Feb-17', 'Feb-18', 'Feb-19', 'Feb-20', 'Feb-21', 'Feb-22', 'Feb-23', 'Feb-24', 'Feb-25', 'Jan-08', 'Jan-09', 'Jan-10', 'Jan-11', 'Jan-12', 'Jan-13', 'Jan-14', 'Jan-15', 'Jan-16', 'Jan-17', 'Jan-18', 'Jan-19', 'Jan-20', 'Jan-21', 'Jan-22', 'Jan-23', 'Jan-24', 'Jan-25', 'Jul-08', 'Jul-09', 'Jul-10', 'Jul-11', 'Jul-12', 'Jul-13', 'Jul-14', 'Jul-15', 'Jul-16', 'Jul-17', 'Jul-18', 'Jul-19', 'Jul-20', 'Jul-21', 'Jul-22', 'Jul-23', 'Jul-24', 'Jun-08', 'Jun-09', 'Jun-10', 'Jun-11', 'Jun-12', 'Jun-13', 'Jun-14', 'Jun-15', 'Jun-16', 'Jun-17', 'Jun-18', 'Jun-19', 'Jun-20', 'Jun-21', 'Jun-22', 'Jun-23', 'Jun-24', 'Mar-08', 'Mar-09', 'Mar-10', 'Mar-11', 'Mar-12', 'Mar-13', 'Mar-14', 'Mar-15', 'Mar-16', 'Mar-17', 'Mar-18', 'Mar-19', 'Mar-20', 'Mar-21', 'Mar-22', 'Mar-23', 'Mar-24', 'Mar-25', 'May-08', 'May-09', 'May-10', 'May-11', 'May-12', 'May-13', 'May-14', 'May-15', 'May-16', 'May-17', 'May-18', 'May-19', 'May-20', 'May-21', 'May-22', 'May-23', 'May-24', 'May-25', 'Nov-08', 'Nov-09', 'Nov-10', 'Nov-11', 'Nov-12', 'Nov-13', 'Nov-14', 'Nov-15', 'Nov-16', 'Nov-17', 'Nov-18', 'Nov-19', 'Nov-20', 'Nov-21', 'Nov-22', 'Nov-23', 'Nov-24', 'Oct-08', 'Oct-09', 'Oct-10', 'Oct-11', 'Oct-12', 'Oct-13', 'Oct-14', 'Oct-15', 'Oct-16', 'Oct-17', 'Oct-18', 'Oct-19', 'Oct-20', 'Oct-21', 'Oct-22', 'Oct-23', 'Oct-24', 'Sep-08', 'Sep-09', 'Sep-10', 'Sep-11', 'Sep-12', 'Sep-13', 'Sep-14', 'Sep-15', 'Sep-16', 'Sep-17', 'Sep-18', 'Sep-19', 'Sep-20', 'Sep-21', 'Sep-22', 'Sep-23', 'Sep-24']
#
# Direct datetime conversion failed, analyzing time format...
# Sample time format: Jul-16
# C:\Users\osmon\AppData\Local\Temp\ipykernel_29728\4029451490.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['DateTime'] = pd.to_datetime(df[time_col])

# %%
# Temporal export analysis
if datetime_conversion_success:
    # Monthly export analysis
    monthly_exports_value = df.groupby('Month')[amount_col].sum()
    monthly_exports_weight = df.groupby('Month')[quantity_col].sum()
    
    # Create month names for better visualization
    month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                   'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    
    # Plot monthly trends
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))
    
    # Monthly export values
    ax1.plot(range(1, 13), [monthly_exports_value.get(i, 0) for i in range(1, 13)], 
             marker='o', linewidth=2, markersize=8, color='blue')
    ax1.set_title('Monthly Export Values Throughout the Year', fontsize=14, fontweight='bold')
    ax1.set_ylabel('Export Value ($US)', fontsize=12)
    ax1.set_xticks(range(1, 13))
    ax1.set_xticklabels(month_names)
    ax1.grid(True, alpha=0.3)
    ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))
    
    # Monthly export weights
    ax2.plot(range(1, 13), [monthly_exports_weight.get(i, 0) for i in range(1, 13)], 
             marker='s', linewidth=2, markersize=8, color='red')
    ax2.set_title('Monthly Export Weights Throughout the Year', fontsize=14, fontweight='bold')
    ax2.set_ylabel('Export Weight (kg)', fontsize=12)
    ax2.set_xlabel('Month', fontsize=12)
    ax2.set_xticks(range(1, 13))
    ax2.set_xticklabels(month_names)
    ax2.grid(True, alpha=0.3)
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1e6:.1f}M kg'))
    
    plt.tight_layout()
    plt.show()
    
    # Print monthly statistics
    print('=== MONTHLY EXPORT ANALYSIS ===\n')
    for month in range(1, 13):
        value = monthly_exports_value.get(month, 0)
        weight = monthly_exports_weight.get(month, 0)
        print(f'{month_names[month-1]}: ${value:,.0f} ({weight:,.0f} kg)')
        
else:
    # Fallback analysis using time periods as-is
    time_exports_value = df.groupby(time_col)[amount_col].sum().sort_index()
    time_exports_weight = df.groupby(time_col)[quantity_col].sum().sort_index()
    
    print('=== EXPORT ANALYSIS BY TIME PERIOD ===\n')
    print('Export values by time period:')
    for period, value in time_exports_value.items():
        weight = time_exports_weight.get(period, 0)
        print(f'{period}: ${value:,.0f} ({weight:,.0f} kg)')
    
    # Plot time series
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8))
    
    time_exports_value.plot(kind='bar', ax=ax1, color='skyblue')
    ax1.set_title('Export Values by Time Period')
    ax1.set_ylabel('Export Value ($US)')
    ax1.tick_params(axis='x', rotation=45)
    
    time_exports_weight.plot(kind='bar', ax=ax2, color='lightcoral')
    ax2.set_title('Export Weights by Time Period')
    ax2.set_ylabel('Export Weight (kg)')
    ax2.set_xlabel('Time Period')
    ax2.tick_params(axis='x', rotation=45)
    
    plt.tight_layout()
    plt.show()
# Out:
# === EXPORT ANALYSIS BY TIME PERIOD ===
#
# Export values by time period:
# Apr-08: $1,878,006,903 (1,021,385,248 kg)
# Apr-09: $1,179,146,863 (1,107,055,401 kg)
# Apr-10: $1,481,710,259 (1,057,690,733 kg)
# Apr-11: $2,185,767,739 (1,406,300,165 kg)
# Apr-12: $2,744,289,212 (1,640,428,612 kg)
# Apr-13: $2,076,214,359 (1,583,886,715 kg)
# Apr-14: $2,119,304,512 (1,691,410,224 kg)
# Apr-15: $1,840,783,151 (1,306,642,043 kg)
# Apr-16: $1,397,070,394 (1,102,410,903 kg)
# Apr-17: $1,672,358,031 (1,658,483,426 kg)
# Apr-18: $1,672,206,758 (1,328,610,869 kg)
# Apr-19: $1,750,697,209 (1,290,640,572 kg)
# Apr-20: $1,211,729,140 (687,687,146 kg)
# Apr-21: $1,684,562,590 (917,220,992 kg)
# Apr-22: $1,670,074,519 (975,354,571 kg)
# Apr-23: $1,769,647,920 (1,010,389,699 kg)
# Apr-24: $1,856,310,490 (1,070,274,878 kg)
# Apr-25: $2,018,261,664 (823,311,286 kg)
# Aug-08: $2,175,833,706 (1,295,912,197 kg)
# Aug-09: $1,230,877,043 (1,307,950,300 kg)
# Aug-10: $1,568,262,063 (1,003,000,048 kg)
# Aug-11: $2,142,963,731 (1,395,049,483 kg)
# Aug-12: $2,426,178,984 (1,418,729,467 kg)
# Aug-13: $2,046,502,706 (1,529,697,191 kg)
# Aug-14: $1,940,151,478 (1,853,425,127 kg)
# Aug-15: $1,575,394,138 (1,138,193,990 kg)
# Aug-16: $1,526,007,089 (1,673,022,041 kg)
# Aug-17: $1,677,978,154 (1,528,136,129 kg)
# Aug-18: $1,668,808,095 (1,670,021,479 kg)
# Aug-19: $1,381,064,239 (883,449,364 kg)
# Aug-20: $1,222,914,249 (854,551,243 kg)
# Aug-21: $1,375,873,923 (787,266,056 kg)
# Aug-22: $1,720,129,815 (925,818,903 kg)
# Aug-23: $1,742,524,697 (1,020,892,294 kg)
# Aug-24: $1,936,344,680 (998,468,475 kg)
# Dec-08: $1,449,800,998 (969,487,316 kg)
# Dec-09: $1,373,079,647 (1,322,638,619 kg)
# Dec-10: $1,670,419,764 (1,409,382,795 kg)
# Dec-11: $2,494,706,099 (1,811,311,096 kg)
# Dec-12: $2,168,817,980 (1,595,129,269 kg)
# Dec-13: $2,406,576,771 (2,678,590,811 kg)
# Dec-14: $1,907,649,794 (1,778,575,946 kg)
# Dec-15: $1,721,231,776 (1,763,561,104 kg)
# Dec-16: $1,800,217,246 (2,099,567,436 kg)
# Dec-17: $1,736,702,390 (1,879,139,038 kg)
# Dec-18: $1,490,748,359 (911,542,619 kg)
# Dec-19: $1,323,625,899 (761,104,213 kg)
# Dec-20: $1,517,248,322 (1,186,526,269 kg)
# Dec-21: $1,470,473,059 (933,119,709 kg)
# Dec-22: $1,907,613,016 (1,677,295,541 kg)
# Dec-23: $2,033,579,730 (1,777,481,346 kg)
# Dec-24: $2,171,026,192 (1,647,678,038 kg)
# Feb-08: $1,617,724,141 (1,215,266,668 kg)
# Feb-09: $1,252,330,974 (984,154,719 kg)
# Feb-10: $1,323,874,872 (1,203,035,039 kg)
# Feb-11: $1,726,068,414 (1,239,060,863 kg)
# Feb-12: $2,279,830,891 (1,304,895,340 kg)
# Feb-13: $1,941,614,348 (1,287,744,784 kg)
# Feb-14: $2,065,857,939 (1,791,083,534 kg)
# Feb-15: $1,632,044,628 (1,377,894,703 kg)
# Feb-16: $1,632,291,187 (2,018,116,144 kg)
# Feb-17: $1,511,997,143 (1,709,846,780 kg)
# Feb-18: $1,464,930,863 (1,396,549,558 kg)
# Feb-19: $1,359,010,304 (1,133,579,559 kg)
# Feb-20: $1,263,776,448 (761,875,312 kg)
# Feb-21: $1,387,002,132 (961,485,008 kg)
# Feb-22: $1,358,995,969 (829,146,474 kg)
# Feb-23: $1,933,054,316 (1,311,264,153 kg)
# Feb-24: $1,995,823,847 (1,319,341,436 kg)
# Feb-25: $1,765,092,235 (865,017,560 kg)
# Jan-08: $1,436,591,783 (931,736,273 kg)
# Jan-09: $1,194,478,557 (950,872,035 kg)
# Jan-10: $1,316,570,154 (1,245,947,914 kg)
# Jan-11: $1,911,927,496 (1,613,833,852 kg)
# Jan-12: $2,169,420,497 (1,326,312,196 kg)
# Jan-13: $1,776,010,100 (1,268,566,685 kg)
# Jan-14: $2,259,305,240 (2,729,689,397 kg)
# Jan-15: $1,679,987,231 (1,822,102,967 kg)
# Jan-16: $1,363,601,532 (1,353,532,049 kg)
# Jan-17: $1,737,272,654 (2,159,232,734 kg)
# Jan-18: $1,380,574,685 (1,322,578,797 kg)
# Jan-19: $1,398,713,015 (1,297,346,936 kg)
# Jan-20: $1,206,771,176 (937,133,336 kg)
# Jan-21: $1,281,219,674 (1,003,706,082 kg)
# Jan-22: $1,359,395,958 (769,109,089 kg)
# Jan-23: $1,824,104,510 (1,637,290,545 kg)
# Jan-24: $1,933,365,618 (1,571,628,146 kg)
# Jan-25: $1,737,882,356 (1,071,813,343 kg)
# Jul-08: $1,824,971,986 (1,237,487,919 kg)
# Jul-09: $1,135,365,550 (973,101,640 kg)
# Jul-10: $1,499,672,507 (975,595,761 kg)
# Jul-11: $2,422,557,911 (1,485,569,698 kg)
# Jul-12: $2,447,464,865 (1,749,589,966 kg)
# Jul-13: $1,846,589,501 (1,441,371,294 kg)
# Jul-14: $1,755,561,926 (1,657,554,945 kg)
# Jul-15: $1,613,307,635 (1,368,112,155 kg)
# Jul-16: $1,429,924,557 (1,477,577,021 kg)
# Jul-17: $1,633,028,567 (1,968,807,538 kg)
# Jul-18: $1,539,662,080 (1,260,185,314 kg)
# Jul-19: $1,388,750,666 (803,602,003 kg)
# Jul-20: $1,262,146,583 (855,070,830 kg)
# Jul-21: $1,421,692,457 (828,547,100 kg)
# Jul-22: $1,542,789,504 (948,855,439 kg)
# Jul-23: $1,840,618,490 (971,996,809 kg)
# Jul-24: $2,154,668,204 (871,591,952 kg)
# Jun-08: $1,823,826,446 (1,055,772,734 kg)
# Jun-09: $1,271,643,155 (1,217,981,146 kg)
# Jun-10: $1,634,759,259 (1,009,265,189 kg)
# Jun-11: $2,223,041,285 (1,355,614,045 kg)
# Jun-12: $2,490,895,646 (1,641,115,414 kg)
# Jun-13: $2,063,512,312 (1,463,162,321 kg)
# Jun-14: $1,952,172,056 (1,492,225,456 kg)
# Jun-15: $1,687,656,276 (1,309,394,927 kg)
# Jun-16: $1,384,059,286 (1,265,602,046 kg)
# Jun-17: $1,535,372,785 (1,427,724,574 kg)
# Jun-18: $1,625,862,354 (1,345,576,482 kg)
# Jun-19: $1,498,387,420 (938,507,627 kg)
# Jun-20: $1,161,171,420 (751,570,438 kg)
# Jun-21: $1,456,218,903 (662,981,250 kg)
# Jun-22: $1,879,340,265 (1,217,907,205 kg)
# Jun-23: $1,693,278,175 (815,562,418 kg)
# Jun-24: $1,922,574,236 (861,612,991 kg)
# Mar-08: $1,823,930,157 (1,132,168,352 kg)
# Mar-09: $1,442,829,373 (1,314,067,111 kg)
# Mar-10: $1,410,507,133 (1,102,776,240 kg)
# Mar-11: $2,474,320,099 (1,614,106,694 kg)
# Mar-12: $2,512,794,741 (1,463,227,812 kg)
# Mar-13: $2,195,648,188 (1,525,765,931 kg)
# Mar-14: $2,461,648,140 (2,671,313,039 kg)
# Mar-15: $1,945,113,095 (1,516,937,557 kg)
# Mar-16: $1,541,471,468 (1,564,067,942 kg)
# Mar-17: $1,706,899,248 (1,938,301,018 kg)
# Mar-18: $1,692,583,657 (1,388,223,791 kg)
# Mar-19: $1,721,688,113 (1,329,254,015 kg)
# Mar-20: $1,587,745,018 (828,652,178 kg)
# Mar-21: $1,528,027,664 (768,281,690 kg)
# Mar-22: $1,541,172,346 (791,398,889 kg)
# Mar-23: $2,169,375,402 (1,350,897,199 kg)
# Mar-24: $2,243,408,059 (1,425,005,281 kg)
# Mar-25: $2,195,507,736 (1,149,133,142 kg)
# May-08: $2,047,876,563 (1,108,963,413 kg)
# May-09: $1,199,824,189 (1,218,855,685 kg)
# May-10: $1,531,996,047 (1,042,465,845 kg)
# May-11: $2,204,044,175 (1,235,687,700 kg)
# May-12: $2,625,046,148 (1,723,095,946 kg)
# May-13: $2,084,574,781 (1,217,913,843 kg)
# May-14: $2,053,961,663 (1,773,741,456 kg)
# May-15: $2,019,004,243 (1,405,647,463 kg)
# May-16: $1,328,896,326 (1,118,851,155 kg)
# May-17: $1,645,751,119 (1,504,741,353 kg)
# May-18: $1,670,159,933 (1,206,515,388 kg)
# May-19: $1,521,094,845 (1,087,367,961 kg)
# May-20: $1,326,800,543 (752,956,502 kg)
# May-21: $1,741,556,054 (966,093,408 kg)
# May-22: $1,636,217,845 (803,565,347 kg)
# May-23: $1,817,764,874 (944,444,542 kg)
# May-24: $2,169,140,662 (979,747,275 kg)
# May-25: $1,966,821,288 (855,698,363 kg)
# Nov-08: $1,973,002,540 (1,227,195,586 kg)
# Nov-09: $1,474,411,814 (1,461,260,268 kg)
# Nov-10: $1,653,619,742 (1,284,859,886 kg)
# Nov-11: $2,366,134,237 (1,709,655,110 kg)
# Nov-12: $2,499,152,654 (1,938,218,789 kg)
# Nov-13: $2,594,111,224 (2,964,210,115 kg)
# Nov-14: $1,981,553,357 (1,955,027,494 kg)
# Nov-15: $1,879,907,735 (1,909,107,565 kg)
# Nov-16: $1,782,923,798 (2,527,422,978 kg)
# Nov-17: $1,780,258,649 (2,204,256,602 kg)
# Nov-18: $1,510,256,228 (1,776,409,771 kg)
# Nov-19: $1,341,421,489 (777,612,544 kg)
# Nov-20: $1,471,722,315 (1,175,701,164 kg)
# Nov-21: $1,465,660,105 (806,446,328 kg)
# Nov-22: $1,953,018,757 (1,059,006,456 kg)
# Nov-23: $2,153,165,772 (1,403,055,752 kg)
# Nov-24: $2,863,370,573 (2,246,398,258 kg)
# Oct-08: $1,925,826,119 (1,278,200,129 kg)
# Oct-09: $1,336,020,112 (1,325,028,771 kg)
# Oct-10: $1,942,110,689 (1,319,107,864 kg)
# Oct-11: $2,292,722,048 (1,365,911,092 kg)
# Oct-12: $2,469,609,342 (1,777,398,101 kg)
# Oct-13: $2,510,408,053 (2,570,509,765 kg)
# Oct-14: $2,026,595,079 (1,758,817,867 kg)
# Oct-15: $1,843,111,190 (2,143,490,521 kg)
# Oct-16: $1,999,636,919 (2,352,629,627 kg)
# Oct-17: $1,857,671,434 (2,273,771,079 kg)
# Oct-18: $1,698,277,632 (1,392,128,287 kg)
# Oct-19: $1,405,232,877 (710,327,255 kg)
# Oct-20: $1,457,312,961 (1,174,100,534 kg)
# Oct-21: $1,541,177,528 (928,559,119 kg)
# Oct-22: $1,930,604,126 (1,519,399,409 kg)
# Oct-23: $1,901,961,772 (1,165,618,765 kg)
# Oct-24: $2,042,820,900 (1,478,586,136 kg)
# Sep-08: $2,055,063,260 (1,281,822,965 kg)
# Sep-09: $1,237,279,007 (1,335,645,340 kg)
# Sep-10: $1,518,989,826 (980,332,760 kg)
# Sep-11: $2,290,264,960 (1,651,624,610 kg)
# Sep-12: $2,274,505,011 (1,399,009,485 kg)
# Sep-13: $1,973,751,879 (1,331,262,835 kg)
# Sep-14: $1,960,095,149 (1,638,021,843 kg)
# Sep-15: $1,597,323,779 (1,325,139,286 kg)
# Sep-16: $1,368,834,093 (1,613,601,672 kg)
# Sep-17: $1,550,003,551 (1,486,393,003 kg)
# Sep-18: $1,530,090,995 (1,285,874,991 kg)
# Sep-19: $1,365,539,896 (721,297,217 kg)
# Sep-20: $1,323,141,803 (1,047,725,892 kg)
# Sep-21: $1,413,125,467 (683,945,639 kg)
# Sep-22: $1,835,203,942 (1,110,947,154 kg)
# Sep-23: $1,906,547,017 (1,244,017,840 kg)
# Sep-24: $2,095,147,435 (1,070,900,386 kg)

# %%
# Seasonal commodity analysis
print('\n=== SEASONAL COMMODITY PATTERNS ===\n')

if datetime_conversion_success:
    # Define seasons
    def get_season(month):
        if month in [12, 1, 2]:
            return 'Winter'
        elif month in [3, 4, 5]:
            return 'Spring'
        elif month in [6, 7, 8]:
            return 'Summer'
        else:
            return 'Fall'
    
    df['Season'] = df['Month'].apply(get_season)
    
    # Top commodities by season
    seasons = ['Spring', 'Summer', 'Fall', 'Winter']
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    axes = axes.flatten()
    
    for i, season in enumerate(seasons):
        season_data = df[df['Season'] == season]
        season_commodities = season_data.groupby(commodity_col)[amount_col].sum().sort_values(ascending=False).head(8)
        
        # Plot top commodities for this season
        season_commodities.plot(kind='bar', ax=axes[i], color=plt.cm.Set3(i))
        axes[i].set_title(f'Top Commodities in {season}', fontsize=12, fontweight='bold')
        axes[i].set_ylabel('Export Value ($US)')
        axes[i].tick_params(axis='x', rotation=45, labelsize=8)
        axes[i].yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1e6:.1f}M'))
        
        # Print seasonal analysis
        total_season_value = season_data[amount_col].sum()
        total_season_weight = season_data[quantity_col].sum()
        unique_commodities = season_data[commodity_col].nunique()
        
        print(f'{season}:')
        print(f'  • Total Export Value: ${total_season_value:,.0f}')
        print(f'  • Total Export Weight: {total_season_weight:,.0f} kg')
        print(f'  • Number of Commodities: {unique_commodities}')
        print(f'  • Top 3 Commodities:')
        for j, (commodity, value) in enumerate(season_commodities.head(3).items(), 1):
            percentage = (value / total_season_value) * 100
            print(f'    {j}. {commodity}: ${value:,.0f} ({percentage:.1f}%)')
        print()
    
    plt.tight_layout()
    plt.show()
    
    # Heatmap of commodity exports by month
    commodity_month_pivot = df.pivot_table(
        index=commodity_col, 
        columns='Month', 
        values=amount_col, 
        aggfunc='sum', 
        fill_value=0
    )
    
    # Select top 15 commodities for heatmap
    top_commodities_overall = df.groupby(commodity_col)[amount_col].sum().sort_values(ascending=False).head(15)
    commodity_month_subset = commodity_month_pivot.loc[top_commodities_overall.index]
    
    plt.figure(figsize=(14, 10))
    import seaborn as sns
    sns.heatmap(commodity_month_subset, 
                annot=False, 
                cmap='YlOrRd', 
                cbar_kws={'label': 'Export Value ($US)'})
    plt.title('Monthly Export Patterns by Commodity (Top 15 Commodities)', fontsize=14, fontweight='bold')
    plt.xlabel('Month')
    plt.ylabel('Commodity')
    plt.xticks(range(12), month_names)
    plt.tight_layout()
    plt.show()
    
else:
    # Alternative analysis for non-datetime data
    print('Analyzing commodity patterns by available time periods...')
    
    for period in sorted(df[time_col].unique()):
        period_data = df[df[time_col] == period]
        period_commodities = period_data.groupby(commodity_col)[amount_col].sum().sort_values(ascending=False).head(5)
        
        total_period_value = period_data[amount_col].sum()
        print(f'\n{period}:')
        print(f'  • Total Export Value: ${total_period_value:,.0f}')
        print(f'  • Top 5 Commodities:')
        for j, (commodity, value) in enumerate(period_commodities.items(), 1):
            percentage = (value / total_period_value) * 100
            print(f'    {j}. {commodity}: ${value:,.0f} ({percentage:.1f}%)')

# Summary insights
print('\n=== KEY TEMPORAL INSIGHTS ===')
if datetime_conversion_success:
    peak_month = monthly_exports_value.idxmax()
    lowest_month = monthly_exports_value.idxmin()
    print(f'• Peak export month: {month_names[peak_month-1]} (${monthly_exports_value[peak_month]:,.0f})')
    print(f'• Lowest export month: {month_names[lowest_month-1]} (${monthly_exports_value[lowest_month]:,.0f})')
    
    seasonal_totals = df.groupby('Season')[amount_col].sum().sort_values(ascending=False)
    print(f'• Highest export season: {seasonal_totals.index[0]} (${seasonal_totals.iloc[0]:,.0f})')
    print(f'• Lowest export season: {seasonal_totals.index[-1]} (${seasonal_totals.iloc[-1]:,.0f})')
else:
    peak_period = time_exports_value.idxmax()
    lowest_period = time_exports_value.idxmin()
    print(f'• Peak export period: {peak_period} (${time_exports_value[peak_period]:,.0f})')
    print(f'• Lowest export period: {lowest_period} (${time_exports_value[lowest_period]:,.0f})')
# Out:
# === SEASONAL COMMODITY PATTERNS ===
#
# Analyzing commodity patterns by available time periods...
#
# Apr-08:
#   • Total Export Value: $1,878,006,903
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $509,118,627 (27.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $311,991,939 (16.6%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $122,311,923 (6.5%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $99,591,733 (5.3%)
#     5. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $83,273,399 (4.4%)
#
# Apr-09:
#   • Total Export Value: $1,179,146,863
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $285,295,502 (24.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $187,721,981 (15.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $101,758,672 (8.6%)
#     4. 10 Cereals: $71,293,586 (6.0%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $63,386,721 (5.4%)
#
# Apr-10:
#   • Total Export Value: $1,481,710,259
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $350,505,354 (23.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $345,737,436 (23.3%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $73,838,290 (5.0%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $70,495,525 (4.8%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $64,198,909 (4.3%)
#
# Apr-11:
#   • Total Export Value: $2,185,767,739
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $498,668,173 (22.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $492,801,973 (22.5%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $136,744,356 (6.3%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $92,335,541 (4.2%)
#     5. 38 Miscellaneous Chemical Products: $79,975,813 (3.7%)
#
# Apr-12:
#   • Total Export Value: $2,744,289,212
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $762,093,973 (27.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $669,960,404 (24.4%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $128,803,895 (4.7%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $105,736,120 (3.9%)
#     5. 74 Copper And Articles Thereof: $96,971,505 (3.5%)
#
# Apr-13:
#   • Total Export Value: $2,076,214,359
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $495,874,417 (23.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $428,330,917 (20.6%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $116,552,783 (5.6%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $92,456,821 (4.5%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $90,852,701 (4.4%)
#
# Apr-14:
#   • Total Export Value: $2,119,304,512
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $478,928,065 (22.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $440,206,726 (20.8%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $110,710,587 (5.2%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $109,023,036 (5.1%)
#     5. 10 Cereals: $95,695,601 (4.5%)
#
# Apr-15:
#   • Total Export Value: $1,840,783,151
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $372,484,309 (20.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $267,351,513 (14.5%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $179,501,050 (9.8%)
#     4. 38 Miscellaneous Chemical Products: $91,536,148 (5.0%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $80,966,911 (4.4%)
#
# Apr-16:
#   • Total Export Value: $1,397,070,394
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $324,640,838 (23.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $153,888,354 (11.0%)
#     3. 39 Plastics And Articles Thereof: $73,703,835 (5.3%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $72,751,914 (5.2%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $65,808,822 (4.7%)
#
# Apr-17:
#   • Total Export Value: $1,672,358,031
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $366,285,196 (21.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $240,694,998 (14.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $134,133,858 (8.0%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $78,336,949 (4.7%)
#     5. 39 Plastics And Articles Thereof: $65,922,280 (3.9%)
#
# Apr-18:
#   • Total Export Value: $1,672,206,758
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $372,421,573 (22.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $262,599,457 (15.7%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $88,177,656 (5.3%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $76,972,221 (4.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $75,993,574 (4.5%)
#
# Apr-19:
#   • Total Export Value: $1,750,697,209
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $380,724,093 (21.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $332,743,541 (19.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $92,325,424 (5.3%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $76,409,501 (4.4%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $73,760,969 (4.2%)
#
# Apr-20:
#   • Total Export Value: $1,211,729,140
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $249,407,711 (20.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $210,264,427 (17.4%)
#     3. 38 Miscellaneous Chemical Products: $69,332,467 (5.7%)
#     4. 02 Meat And Edible Meat Offal: $63,532,662 (5.2%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $62,241,182 (5.1%)
#
# Apr-21:
#   • Total Export Value: $1,684,562,590
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $334,033,909 (19.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $330,760,925 (19.6%)
#     3. 02 Meat And Edible Meat Offal: $81,512,844 (4.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $77,303,963 (4.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $70,460,866 (4.2%)
#
# Apr-22:
#   • Total Export Value: $1,670,074,519
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $295,018,206 (17.7%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $276,926,016 (16.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $96,301,787 (5.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $96,213,028 (5.8%)
#     5. 22 Beverages, Spirits And Vinegar: $81,148,166 (4.9%)
#
# Apr-23:
#   • Total Export Value: $1,769,647,920
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $414,290,075 (23.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $334,332,819 (18.9%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $94,302,473 (5.3%)
#     4. 02 Meat And Edible Meat Offal: $74,167,979 (4.2%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $69,720,468 (3.9%)
#
# Apr-24:
#   • Total Export Value: $1,856,310,490
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $343,616,101 (18.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $248,616,231 (13.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $146,773,412 (7.9%)
#     4. 30 Pharmaceutical Products: $108,249,141 (5.8%)
#     5. 38 Miscellaneous Chemical Products: $93,718,414 (5.0%)
#
# Apr-25:
#   • Total Export Value: $2,018,261,664
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $418,922,638 (20.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $386,300,519 (19.1%)
#     3. 30 Pharmaceutical Products: $135,511,678 (6.7%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $92,963,692 (4.6%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $78,012,491 (3.9%)
#
# Aug-08:
#   • Total Export Value: $2,175,833,706
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $526,429,481 (24.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $354,699,636 (16.3%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $177,659,917 (8.2%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $134,764,679 (6.2%)
#     5. 72 Iron And Steel: $120,159,235 (5.5%)
#
# Aug-09:
#   • Total Export Value: $1,230,877,043
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $216,517,602 (17.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $172,855,974 (14.0%)
#     3. 10 Cereals: $78,692,295 (6.4%)
#     4. 38 Miscellaneous Chemical Products: $75,223,535 (6.1%)
#     5. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $69,532,109 (5.6%)
#
# Aug-10:
#   • Total Export Value: $1,568,262,063
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $377,263,486 (24.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $319,579,944 (20.4%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $69,353,062 (4.4%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $63,757,638 (4.1%)
#     5. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $63,400,193 (4.0%)
#
# Aug-11:
#   • Total Export Value: $2,142,963,731
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $546,954,296 (25.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $526,433,332 (24.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $82,044,750 (3.8%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $75,331,336 (3.5%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $73,650,671 (3.4%)
#
# Aug-12:
#   • Total Export Value: $2,426,178,984
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $633,121,000 (26.1%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $548,031,335 (22.6%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $147,215,070 (6.1%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $119,808,769 (4.9%)
#     5. 38 Miscellaneous Chemical Products: $100,821,835 (4.2%)
#
# Aug-13:
#   • Total Export Value: $2,046,502,706
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $473,799,000 (23.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $412,909,103 (20.2%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $138,593,587 (6.8%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $89,044,845 (4.4%)
#     5. 38 Miscellaneous Chemical Products: $66,731,627 (3.3%)
#
# Aug-14:
#   • Total Export Value: $1,940,151,478
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $416,791,340 (21.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $280,469,546 (14.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $126,205,120 (6.5%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $95,298,096 (4.9%)
#     5. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $88,678,523 (4.6%)
#
# Aug-15:
#   • Total Export Value: $1,575,394,138
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $366,714,202 (23.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $231,216,563 (14.7%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $101,299,326 (6.4%)
#     4. 38 Miscellaneous Chemical Products: $92,820,228 (5.9%)
#     5. 39 Plastics And Articles Thereof: $71,921,442 (4.6%)
#
# Aug-16:
#   • Total Export Value: $1,526,007,089
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $291,639,871 (19.1%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $199,451,773 (13.1%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $133,814,573 (8.8%)
#     4. 38 Miscellaneous Chemical Products: $77,725,709 (5.1%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $77,392,659 (5.1%)
#
# Aug-17:
#   • Total Export Value: $1,677,978,154
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $355,190,578 (21.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $238,136,396 (14.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $156,855,720 (9.3%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $73,409,122 (4.4%)
#     5. 39 Plastics And Articles Thereof: $67,895,410 (4.0%)
#
# Aug-18:
#   • Total Export Value: $1,668,808,095
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $381,094,115 (22.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $298,346,945 (17.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $114,991,863 (6.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $99,958,550 (6.0%)
#     5. 38 Miscellaneous Chemical Products: $73,251,093 (4.4%)
#
# Aug-19:
#   • Total Export Value: $1,381,064,239
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $309,775,063 (22.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $211,677,813 (15.3%)
#     3. 38 Miscellaneous Chemical Products: $75,309,104 (5.5%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $68,248,930 (4.9%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $64,424,728 (4.7%)
#
# Aug-20:
#   • Total Export Value: $1,222,914,249
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $249,307,328 (20.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $208,897,245 (17.1%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $94,945,151 (7.8%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $68,138,881 (5.6%)
#     5. 02 Meat And Edible Meat Offal: $61,726,943 (5.0%)
#
# Aug-21:
#   • Total Export Value: $1,375,873,923
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $260,326,741 (18.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $229,621,558 (16.7%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $122,304,681 (8.9%)
#     4. 38 Miscellaneous Chemical Products: $65,343,582 (4.7%)
#     5. 02 Meat And Edible Meat Offal: $64,827,189 (4.7%)
#
# Aug-22:
#   • Total Export Value: $1,720,129,815
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $316,989,357 (18.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $285,588,193 (16.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $173,841,158 (10.1%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $108,968,249 (6.3%)
#     5. 30 Pharmaceutical Products: $67,210,632 (3.9%)
#
# Aug-23:
#   • Total Export Value: $1,742,524,697
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $414,959,719 (23.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $295,802,081 (17.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $94,790,586 (5.4%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $77,356,561 (4.4%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $70,765,277 (4.1%)
#
# Aug-24:
#   • Total Export Value: $1,936,344,680
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $388,825,218 (20.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $368,175,304 (19.0%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $108,312,411 (5.6%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $93,180,241 (4.8%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $87,828,874 (4.5%)
#
# Dec-08:
#   • Total Export Value: $1,449,800,998
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $438,093,330 (30.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $307,995,426 (21.2%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $104,060,937 (7.2%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $79,683,988 (5.5%)
#     5. 10 Cereals: $62,998,314 (4.3%)
#
# Dec-09:
#   • Total Export Value: $1,373,079,647
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $279,670,494 (20.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $249,303,428 (18.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $145,498,654 (10.6%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $66,932,308 (4.9%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $60,648,802 (4.4%)
#
# Dec-10:
#   • Total Export Value: $1,670,419,764
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $383,006,679 (22.9%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $348,792,794 (20.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $101,960,731 (6.1%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $77,231,514 (4.6%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $69,580,906 (4.2%)
#
# Dec-11:
#   • Total Export Value: $2,494,706,099
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $575,032,290 (23.1%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $528,793,774 (21.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $159,395,554 (6.4%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $144,277,538 (5.8%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $115,047,498 (4.6%)
#
# Dec-12:
#   • Total Export Value: $2,168,817,980
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $608,023,073 (28.0%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $520,900,907 (24.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $91,069,803 (4.2%)
#     4. 38 Miscellaneous Chemical Products: $84,242,052 (3.9%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $80,844,297 (3.7%)
#
# Dec-13:
#   • Total Export Value: $2,406,576,771
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $418,926,091 (17.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $394,574,152 (16.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $358,547,670 (14.9%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $183,270,604 (7.6%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $126,310,452 (5.2%)
#
# Dec-14:
#   • Total Export Value: $1,907,649,794
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $393,637,183 (20.6%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $365,119,322 (19.1%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $220,190,053 (11.5%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $98,251,411 (5.2%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $71,444,426 (3.7%)
#
# Dec-15:
#   • Total Export Value: $1,721,231,776
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $321,654,276 (18.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $286,801,406 (16.7%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $230,862,588 (13.4%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $75,764,480 (4.4%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $72,165,886 (4.2%)
#
# Dec-16:
#   • Total Export Value: $1,800,217,246
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $359,217,307 (20.0%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $337,056,758 (18.7%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $216,753,702 (12.0%)
#     4. 38 Miscellaneous Chemical Products: $84,754,641 (4.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $69,539,364 (3.9%)
#
# Dec-17:
#   • Total Export Value: $1,736,702,390
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $349,755,579 (20.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $271,457,167 (15.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $160,483,870 (9.2%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $85,461,132 (4.9%)
#     5. 38 Miscellaneous Chemical Products: $84,629,617 (4.9%)
#
# Dec-18:
#   • Total Export Value: $1,490,748,359
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $333,996,004 (22.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $257,570,255 (17.3%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $72,894,417 (4.9%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $65,806,459 (4.4%)
#     5. 02 Meat And Edible Meat Offal: $64,429,738 (4.3%)
#
# Dec-19:
#   • Total Export Value: $1,323,625,899
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $267,388,242 (20.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $196,197,577 (14.8%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $85,315,947 (6.4%)
#     4. 02 Meat And Edible Meat Offal: $73,234,526 (5.5%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $72,525,185 (5.5%)
#
# Dec-20:
#   • Total Export Value: $1,517,248,322
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $318,135,721 (21.0%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $245,165,267 (16.2%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $93,214,152 (6.1%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $83,883,898 (5.5%)
#     5. 02 Meat And Edible Meat Offal: $76,301,685 (5.0%)
#
# Dec-21:
#   • Total Export Value: $1,470,473,059
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $244,601,622 (16.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $242,987,576 (16.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $104,123,644 (7.1%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $94,185,127 (6.4%)
#     5. 30 Pharmaceutical Products: $68,062,947 (4.6%)
#
# Dec-22:
#   • Total Export Value: $1,907,613,016
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $350,315,242 (18.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $308,102,524 (16.2%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $274,828,271 (14.4%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $99,362,478 (5.2%)
#     5. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $92,808,619 (4.9%)
#
# Dec-23:
#   • Total Export Value: $2,033,579,730
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $353,284,480 (17.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $322,349,968 (15.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $281,826,875 (13.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $118,866,667 (5.8%)
#     5. 38 Miscellaneous Chemical Products: $79,751,479 (3.9%)
#
# Dec-24:
#   • Total Export Value: $2,171,026,192
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $355,885,690 (16.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $354,848,378 (16.3%)
#     3. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $322,964,041 (14.9%)
#     4. 38 Miscellaneous Chemical Products: $101,839,234 (4.7%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $90,835,185 (4.2%)
#
# Feb-08:
#   • Total Export Value: $1,617,724,141
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $434,593,662 (26.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $291,908,743 (18.0%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $112,099,648 (6.9%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $106,194,239 (6.6%)
#     5. 10 Cereals: $94,792,524 (5.9%)
#
# Feb-09:
#   • Total Export Value: $1,252,330,974
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $287,125,696 (22.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $261,744,473 (20.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $142,540,498 (11.4%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $63,226,192 (5.0%)
#     5. 10 Cereals: $57,557,853 (4.6%)
#
# Feb-10:
#   • Total Export Value: $1,323,874,872
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $269,112,408 (20.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $188,489,152 (14.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $159,778,625 (12.1%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $81,747,648 (6.2%)
#     5. 29 Organic Chemicals: $58,394,164 (4.4%)
#
# Feb-11:
#   • Total Export Value: $1,726,068,414
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $416,905,684 (24.2%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $382,678,429 (22.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $97,479,575 (5.6%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $70,258,456 (4.1%)
#     5. 29 Organic Chemicals: $63,030,672 (3.7%)
#
# Feb-12:
#   • Total Export Value: $2,279,830,891
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $572,068,675 (25.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $531,414,719 (23.3%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $124,611,267 (5.5%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $107,318,842 (4.7%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $92,894,529 (4.1%)
#
# Feb-13:
#   • Total Export Value: $1,941,614,348
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $453,848,184 (23.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $387,953,428 (20.0%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $172,698,139 (8.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $97,763,407 (5.0%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $80,804,206 (4.2%)
#
# Feb-14:
#   • Total Export Value: $2,065,857,939
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $366,761,221 (17.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $355,635,257 (17.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $216,334,122 (10.5%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $207,860,653 (10.1%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $104,213,687 (5.0%)
#
# Feb-15:
#   • Total Export Value: $1,632,044,628
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $327,577,409 (20.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $237,115,935 (14.5%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $100,490,848 (6.2%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $90,667,605 (5.6%)
#     5. 86 Railway Or Tramway Stock Etc; Traffic Signal Equip: $81,286,041 (5.0%)
#
# Feb-16:
#   • Total Export Value: $1,632,291,187
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $298,828,732 (18.3%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $248,139,435 (15.2%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $153,647,323 (9.4%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $102,543,874 (6.3%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $71,078,541 (4.4%)
#
# Feb-17:
#   • Total Export Value: $1,511,997,143
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $336,624,683 (22.3%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $176,219,313 (11.7%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $146,364,530 (9.7%)
#     4. 39 Plastics And Articles Thereof: $66,983,232 (4.4%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $57,449,222 (3.8%)
#
# Feb-18:
#   • Total Export Value: $1,464,930,863
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $338,766,203 (23.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $182,400,307 (12.5%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $78,655,798 (5.4%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $63,374,150 (4.3%)
#     5. 38 Miscellaneous Chemical Products: $61,417,292 (4.2%)
#
# Feb-19:
#   • Total Export Value: $1,359,010,304
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $309,171,866 (22.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $190,804,383 (14.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $74,551,635 (5.5%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $67,714,663 (5.0%)
#     5. 30 Pharmaceutical Products: $63,843,003 (4.7%)
#
# Feb-20:
#   • Total Export Value: $1,263,776,448
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $265,215,771 (21.0%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $228,401,850 (18.1%)
#     3. 02 Meat And Edible Meat Offal: $73,818,629 (5.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $64,545,803 (5.1%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $63,776,812 (5.0%)
#
# Feb-21:
#   • Total Export Value: $1,387,002,132
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $266,669,877 (19.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $230,135,997 (16.6%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $73,685,732 (5.3%)
#     4. 38 Miscellaneous Chemical Products: $67,052,361 (4.8%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $61,646,143 (4.4%)
#
# Feb-22:
#   • Total Export Value: $1,358,995,969
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $224,225,225 (16.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $215,502,949 (15.9%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $101,153,304 (7.4%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $81,097,315 (6.0%)
#     5. 02 Meat And Edible Meat Offal: $62,015,651 (4.6%)
#
# Feb-23:
#   • Total Export Value: $1,933,054,316
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $355,752,778 (18.4%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $313,362,947 (16.2%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $313,057,263 (16.2%)
#     4. 30 Pharmaceutical Products: $125,780,734 (6.5%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $70,840,468 (3.7%)
#
# Feb-24:
#   • Total Export Value: $1,995,823,847
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $348,330,535 (17.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $282,051,761 (14.1%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $240,630,451 (12.1%)
#     4. 30 Pharmaceutical Products: $141,638,971 (7.1%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $100,759,287 (5.0%)
#
# Feb-25:
#   • Total Export Value: $1,765,092,235
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $329,482,411 (18.7%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $319,880,629 (18.1%)
#     3. 30 Pharmaceutical Products: $116,084,662 (6.6%)
#     4. 38 Miscellaneous Chemical Products: $91,395,372 (5.2%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $85,344,868 (4.8%)
#
# Jan-08:
#   • Total Export Value: $1,436,591,783
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $358,552,627 (25.0%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $257,512,188 (17.9%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $107,213,207 (7.5%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $77,521,579 (5.4%)
#     5. 10 Cereals: $68,308,112 (4.8%)
#
# Jan-09:
#   • Total Export Value: $1,194,478,557
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $316,298,453 (26.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $213,480,607 (17.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $135,448,682 (11.3%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $72,377,188 (6.1%)
#     5. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $50,793,737 (4.3%)
#
# Jan-10:
#   • Total Export Value: $1,316,570,154
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $227,171,891 (17.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $172,495,866 (13.1%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $132,397,225 (10.1%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $124,309,918 (9.4%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $60,096,289 (4.6%)
#
# Jan-11:
#   • Total Export Value: $1,911,927,496
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $369,870,178 (19.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $355,308,580 (18.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $228,628,906 (12.0%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $154,159,884 (8.1%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $92,609,487 (4.8%)
#
# Jan-12:
#   • Total Export Value: $2,169,420,497
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $609,868,366 (28.1%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $510,268,703 (23.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $91,475,743 (4.2%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $83,948,288 (3.9%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $80,985,030 (3.7%)
#
# Jan-13:
#   • Total Export Value: $1,776,010,100
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $399,197,747 (22.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $319,848,062 (18.0%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $154,987,680 (8.7%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $81,965,165 (4.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $75,386,984 (4.2%)
#
# Jan-14:
#   • Total Export Value: $2,259,305,240
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $385,459,564 (17.1%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $328,719,756 (14.5%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $325,003,250 (14.4%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $229,512,488 (10.2%)
#     5. 10 Cereals: $139,708,063 (6.2%)
#
# Jan-15:
#   • Total Export Value: $1,679,987,231
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $308,763,435 (18.4%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $300,794,047 (17.9%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $261,542,007 (15.6%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $60,316,809 (3.6%)
#     5. 39 Plastics And Articles Thereof: $58,860,564 (3.5%)
#
# Jan-16:
#   • Total Export Value: $1,363,601,532
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $256,282,966 (18.8%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $204,338,838 (15.0%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $133,157,865 (9.8%)
#     4. 90 Optic, Photo Etc, Medic Or Surgical Instrments Etc: $71,117,575 (5.2%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $67,877,322 (5.0%)
#
# Jan-17:
#   • Total Export Value: $1,737,272,654
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $333,136,996 (19.2%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $266,043,139 (15.3%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $244,218,783 (14.1%)
#     4. 10 Cereals: $79,646,644 (4.6%)
#     5. 38 Miscellaneous Chemical Products: $77,640,001 (4.5%)
#
# Jan-18:
#   • Total Export Value: $1,380,574,685
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $308,284,961 (22.3%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $137,112,053 (9.9%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $134,170,819 (9.7%)
#     4. 38 Miscellaneous Chemical Products: $75,835,207 (5.5%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $65,781,976 (4.8%)
#
# Jan-19:
#   • Total Export Value: $1,398,713,015
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $297,053,670 (21.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $215,104,514 (15.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $81,903,862 (5.9%)
#     4. 38 Miscellaneous Chemical Products: $79,209,191 (5.7%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $75,832,609 (5.4%)
#
# Jan-20:
#   • Total Export Value: $1,206,771,176
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $230,835,960 (19.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $209,092,690 (17.3%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $93,396,870 (7.7%)
#     4. 02 Meat And Edible Meat Offal: $68,660,651 (5.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $61,224,487 (5.1%)
#
# Jan-21:
#   • Total Export Value: $1,281,219,674
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $225,948,741 (17.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $217,276,138 (17.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $88,884,132 (6.9%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $68,768,156 (5.4%)
#     5. 38 Miscellaneous Chemical Products: $66,272,037 (5.2%)
#
# Jan-22:
#   • Total Export Value: $1,359,395,958
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $291,924,420 (21.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $255,126,100 (18.8%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $100,375,580 (7.4%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $65,618,880 (4.8%)
#     5. 38 Miscellaneous Chemical Products: $63,152,247 (4.6%)
#
# Jan-23:
#   • Total Export Value: $1,824,104,510
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $318,622,668 (17.5%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $302,943,814 (16.6%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $216,220,279 (11.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $97,180,210 (5.3%)
#     5. 38 Miscellaneous Chemical Products: $76,206,914 (4.2%)
#
# Jan-24:
#   • Total Export Value: $1,933,365,618
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $393,873,605 (20.4%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $308,830,339 (16.0%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $252,174,402 (13.0%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $88,890,119 (4.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $78,475,850 (4.1%)
#
# Jan-25:
#   • Total Export Value: $1,737,882,356
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $306,746,500 (17.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $270,171,628 (15.5%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $257,036,848 (14.8%)
#     4. 30 Pharmaceutical Products: $78,985,476 (4.5%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $75,852,434 (4.4%)
#
# Jul-08:
#   • Total Export Value: $1,824,971,986
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $472,275,112 (25.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $330,293,741 (18.1%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $98,619,571 (5.4%)
#     4. 72 Iron And Steel: $94,581,517 (5.2%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $85,390,813 (4.7%)
#
# Jul-09:
#   • Total Export Value: $1,135,365,550
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $212,551,224 (18.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $186,775,635 (16.5%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $89,443,856 (7.9%)
#     4. 38 Miscellaneous Chemical Products: $64,793,271 (5.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $55,503,909 (4.9%)
#
# Jul-10:
#   • Total Export Value: $1,499,672,507
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $368,110,927 (24.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $327,213,543 (21.8%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $77,269,287 (5.2%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $66,460,022 (4.4%)
#     5. 39 Plastics And Articles Thereof: $59,581,412 (4.0%)
#
# Jul-11:
#   • Total Export Value: $2,422,557,911
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $648,846,654 (26.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $548,932,636 (22.7%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $183,638,625 (7.6%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $91,520,572 (3.8%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $86,927,332 (3.6%)
#
# Jul-12:
#   • Total Export Value: $2,447,464,865
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $733,609,388 (30.0%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $593,978,332 (24.3%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $107,895,310 (4.4%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $105,939,160 (4.3%)
#     5. 29 Organic Chemicals: $79,485,945 (3.2%)
#
# Jul-13:
#   • Total Export Value: $1,846,589,501
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $456,553,734 (24.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $272,725,008 (14.8%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $132,722,546 (7.2%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $85,420,289 (4.6%)
#     5. 86 Railway Or Tramway Stock Etc; Traffic Signal Equip: $84,503,015 (4.6%)
#
# Jul-14:
#   • Total Export Value: $1,755,561,926
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $410,294,474 (23.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $256,858,516 (14.6%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $117,029,029 (6.7%)
#     4. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $100,414,930 (5.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $76,912,301 (4.4%)
#
# Jul-15:
#   • Total Export Value: $1,613,307,635
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $351,053,758 (21.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $263,132,097 (16.3%)
#     3. 30 Pharmaceutical Products: $90,066,162 (5.6%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $89,876,753 (5.6%)
#     5. 38 Miscellaneous Chemical Products: $80,953,405 (5.0%)
#
# Jul-16:
#   • Total Export Value: $1,429,924,557
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $327,346,540 (22.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $162,623,709 (11.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $98,398,346 (6.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $88,603,236 (6.2%)
#     5. 38 Miscellaneous Chemical Products: $70,150,079 (4.9%)
#
# Jul-17:
#   • Total Export Value: $1,633,028,567
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $356,509,617 (21.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $214,598,019 (13.1%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $119,230,811 (7.3%)
#     4. 10 Cereals: $79,807,763 (4.9%)
#     5. 38 Miscellaneous Chemical Products: $79,448,299 (4.9%)
#
# Jul-18:
#   • Total Export Value: $1,539,662,080
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $361,072,534 (23.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $286,336,117 (18.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $95,222,883 (6.2%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $75,239,555 (4.9%)
#     5. 38 Miscellaneous Chemical Products: $69,344,976 (4.5%)
#
# Jul-19:
#   • Total Export Value: $1,388,750,666
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $317,134,875 (22.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $255,109,049 (18.4%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $80,942,209 (5.8%)
#     4. 38 Miscellaneous Chemical Products: $69,674,713 (5.0%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $60,634,126 (4.4%)
#
# Jul-20:
#   • Total Export Value: $1,262,146,583
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $289,479,865 (22.9%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $248,851,755 (19.7%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $111,289,515 (8.8%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $62,794,268 (5.0%)
#     5. 02 Meat And Edible Meat Offal: $59,228,927 (4.7%)
#
# Jul-21:
#   • Total Export Value: $1,421,692,457
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $282,243,503 (19.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $246,740,456 (17.4%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $79,620,506 (5.6%)
#     4. 02 Meat And Edible Meat Offal: $64,511,730 (4.5%)
#     5. 38 Miscellaneous Chemical Products: $64,243,908 (4.5%)
#
# Jul-22:
#   • Total Export Value: $1,542,789,504
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $307,291,877 (19.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $214,783,413 (13.9%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $120,228,535 (7.8%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $105,242,723 (6.8%)
#     5. 02 Meat And Edible Meat Offal: $73,815,802 (4.8%)
#
# Jul-23:
#   • Total Export Value: $1,840,618,490
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $391,154,347 (21.3%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $365,464,784 (19.9%)
#     3. 29 Organic Chemicals: $180,988,963 (9.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $80,829,161 (4.4%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $77,793,600 (4.2%)
#
# Jul-24:
#   • Total Export Value: $2,154,668,204
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $360,947,585 (16.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $345,393,080 (16.0%)
# ...
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $435,635,348 (15.2%)
#     3. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $341,159,120 (11.9%)
#     4. 30 Pharmaceutical Products: $131,319,137 (4.6%)
#     5. 39 Plastics And Articles Thereof: $112,052,684 (3.9%)
#
# Oct-08:
#   • Total Export Value: $1,925,826,119
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $532,940,830 (27.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $283,117,471 (14.7%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $128,296,904 (6.7%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $100,785,184 (5.2%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $93,938,594 (4.9%)
#
# Oct-09:
#   • Total Export Value: $1,336,020,112
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $266,223,799 (19.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $218,790,924 (16.4%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $105,359,832 (7.9%)
#     4. 10 Cereals: $75,856,918 (5.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $64,291,446 (4.8%)
#
# Oct-10:
#   • Total Export Value: $1,942,110,689
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $602,001,442 (31.0%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $390,806,885 (20.1%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $113,800,217 (5.9%)
#     4. 38 Miscellaneous Chemical Products: $70,470,738 (3.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $68,610,743 (3.5%)
#
# Oct-11:
#   • Total Export Value: $2,292,722,048
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $591,771,089 (25.8%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $563,230,237 (24.6%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $154,473,789 (6.7%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $86,981,263 (3.8%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $81,128,291 (3.5%)
#
# Oct-12:
#   • Total Export Value: $2,469,609,342
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $628,271,039 (25.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $517,314,568 (20.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $318,104,238 (12.9%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $102,424,462 (4.1%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $97,480,283 (3.9%)
#
# Oct-13:
#   • Total Export Value: $2,510,408,053
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $530,334,596 (21.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $456,100,527 (18.2%)
#     3. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $427,042,481 (17.0%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $129,604,319 (5.2%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $91,576,781 (3.6%)
#
# Oct-14:
#   • Total Export Value: $2,026,595,079
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $437,825,390 (21.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $380,137,856 (18.8%)
#     3. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $115,562,667 (5.7%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $97,692,226 (4.8%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $91,397,447 (4.5%)
#
# Oct-15:
#   • Total Export Value: $1,843,111,190
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $349,497,623 (19.0%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $314,519,814 (17.1%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $280,568,211 (15.2%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $82,068,525 (4.5%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $75,610,280 (4.1%)
#
# Oct-16:
#   • Total Export Value: $1,999,636,919
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $486,766,637 (24.3%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $366,805,680 (18.3%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $208,463,373 (10.4%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $93,129,514 (4.7%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $80,946,332 (4.0%)
#
# Oct-17:
#   • Total Export Value: $1,857,671,434
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $363,952,367 (19.6%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $350,786,406 (18.9%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $229,160,837 (12.3%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $84,965,614 (4.6%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $74,643,904 (4.0%)
#
# Oct-18:
#   • Total Export Value: $1,698,277,632
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $361,129,134 (21.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $354,772,057 (20.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $101,384,342 (6.0%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $85,035,379 (5.0%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $82,563,022 (4.9%)
#
# Oct-19:
#   • Total Export Value: $1,405,232,877
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $314,523,740 (22.4%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $253,623,485 (18.0%)
#     3. 30 Pharmaceutical Products: $84,888,705 (6.0%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $71,325,857 (5.1%)
#     5. 39 Plastics And Articles Thereof: $55,499,133 (3.9%)
#
# Oct-20:
#   • Total Export Value: $1,457,312,961
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $243,643,470 (16.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $229,475,435 (15.7%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $126,286,660 (8.7%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $93,820,502 (6.4%)
#     5. 22 Beverages, Spirits And Vinegar: $86,220,488 (5.9%)
#
# Oct-21:
#   • Total Export Value: $1,541,177,528
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $294,960,826 (19.1%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $251,638,466 (16.3%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $106,875,587 (6.9%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $104,828,757 (6.8%)
#     5. 38 Miscellaneous Chemical Products: $78,630,398 (5.1%)
#
# Oct-22:
#   • Total Export Value: $1,930,604,126
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $375,662,175 (19.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $341,749,086 (17.7%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $216,126,488 (11.2%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $85,638,434 (4.4%)
#     5. 38 Miscellaneous Chemical Products: $70,131,362 (3.6%)
#
# Oct-23:
#   • Total Export Value: $1,901,961,772
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $376,073,276 (19.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $352,191,799 (18.5%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $226,850,634 (11.9%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $80,362,590 (4.2%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $75,546,506 (4.0%)
#
# Oct-24:
#   • Total Export Value: $2,042,820,900
#   • Top 5 Commodities:
#     1. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $434,007,354 (21.2%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $303,948,649 (14.9%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $300,316,438 (14.7%)
#     4. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $76,255,142 (3.7%)
#     5. 30 Pharmaceutical Products: $76,079,058 (3.7%)
#
# Sep-08:
#   • Total Export Value: $2,055,063,260
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $518,834,063 (25.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $372,051,622 (18.1%)
#     3. 38 Miscellaneous Chemical Products: $132,380,321 (6.4%)
#     4. 31 Fertilizers: $101,742,389 (5.0%)
#     5. 72 Iron And Steel: $99,001,089 (4.8%)
#
# Sep-09:
#   • Total Export Value: $1,237,279,007
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $217,286,848 (17.6%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $168,341,610 (13.6%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $163,429,057 (13.2%)
#     4. 10 Cereals: $57,004,328 (4.6%)
#     5. 29 Organic Chemicals: $53,486,047 (4.3%)
#
# Sep-10:
#   • Total Export Value: $1,518,989,826
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $371,122,568 (24.4%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $353,069,763 (23.2%)
#     3. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $72,089,912 (4.7%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $67,157,625 (4.4%)
#     5. 38 Miscellaneous Chemical Products: $63,507,188 (4.2%)
#
# Sep-11:
#   • Total Export Value: $2,290,264,960
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $503,836,283 (22.0%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $450,905,983 (19.7%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $215,237,199 (9.4%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $124,451,733 (5.4%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $95,602,120 (4.2%)
#
# Sep-12:
#   • Total Export Value: $2,274,505,011
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $609,681,345 (26.8%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $533,622,837 (23.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $101,026,296 (4.4%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $93,023,977 (4.1%)
#     5. 29 Organic Chemicals: $70,620,456 (3.1%)
#
# Sep-13:
#   • Total Export Value: $1,973,751,879
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $448,525,011 (22.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $389,988,674 (19.8%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $114,590,066 (5.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $105,558,848 (5.3%)
#     5. 27 Mineral Fuel, Oil Etc.; Bitumin Subst; Mineral Wax: $94,536,053 (4.8%)
#
# Sep-14:
#   • Total Export Value: $1,960,095,149
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $448,130,094 (22.9%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $381,530,129 (19.5%)
#     3. 28 Inorg Chem; Prec & Rare-earth Met & Radioact Compd: $105,276,019 (5.4%)
#     4. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $98,611,113 (5.0%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $88,062,972 (4.5%)
#
# Sep-15:
#   • Total Export Value: $1,597,323,779
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $343,187,539 (21.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $311,195,390 (19.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $82,776,465 (5.2%)
#     4. 38 Miscellaneous Chemical Products: $71,450,774 (4.5%)
#     5. 39 Plastics And Articles Thereof: $63,412,184 (4.0%)
#
# Sep-16:
#   • Total Export Value: $1,368,834,093
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $287,521,613 (21.0%)
#     2. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $139,078,399 (10.2%)
#     3. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $132,126,397 (9.7%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $68,325,120 (5.0%)
#     5. 38 Miscellaneous Chemical Products: $63,640,159 (4.6%)
#
# Sep-17:
#   • Total Export Value: $1,550,003,551
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $308,652,891 (19.9%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $234,981,582 (15.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $106,410,749 (6.9%)
#     4. 38 Miscellaneous Chemical Products: $79,364,195 (5.1%)
#     5. 39 Plastics And Articles Thereof: $64,555,690 (4.2%)
#
# Sep-18:
#   • Total Export Value: $1,530,090,995
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $339,919,997 (22.2%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $265,800,984 (17.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $104,278,460 (6.8%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $86,923,441 (5.7%)
#     5. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $70,787,047 (4.6%)
#
# Sep-19:
#   • Total Export Value: $1,365,539,896
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $294,090,608 (21.5%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $242,828,925 (17.8%)
#     3. 30 Pharmaceutical Products: $87,862,163 (6.4%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $70,739,125 (5.2%)
#     5. 38 Miscellaneous Chemical Products: $57,628,511 (4.2%)
#
# Sep-20:
#   • Total Export Value: $1,323,141,803
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $269,002,881 (20.3%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $258,289,806 (19.5%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $114,029,891 (8.6%)
#     4. 85 Electric Machinery Etc; Sound Equip; Tv Equip; Pts: $67,594,821 (5.1%)
#     5. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $62,849,393 (4.8%)
#
# Sep-21:
#   • Total Export Value: $1,413,125,467
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $272,183,691 (19.3%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $268,478,104 (19.0%)
#     3. 23 Food Industry Residues & Waste; Prep Animal Feed: $97,711,403 (6.9%)
#     4. 38 Miscellaneous Chemical Products: $77,645,245 (5.5%)
#     5. 02 Meat And Edible Meat Offal: $63,186,731 (4.5%)
#
# Sep-22:
#   • Total Export Value: $1,835,203,942
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $380,560,282 (20.7%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $264,176,313 (14.4%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $210,349,107 (11.5%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $114,716,048 (6.3%)
#     5. 30 Pharmaceutical Products: $98,904,836 (5.4%)
#
# Sep-23:
#   • Total Export Value: $1,906,547,017
#   • Top 5 Commodities:
#     1. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $399,599,318 (21.0%)
#     2. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $303,627,433 (15.9%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $198,160,598 (10.4%)
#     4. 23 Food Industry Residues & Waste; Prep Animal Feed: $86,115,416 (4.5%)
#     5. 30 Pharmaceutical Products: $84,110,805 (4.4%)
#
# Sep-24:
#   • Total Export Value: $2,095,147,435
#   • Top 5 Commodities:
#     1. 87 Vehicles, Except Railway Or Tramway, And Parts Etc: $408,223,128 (19.5%)
#     2. 84 Nuclear Reactors, Boilers, Machinery Etc.; Parts: $360,007,059 (17.2%)
#     3. 12 Oil Seeds Etc.; Misc Grain, Seed, Fruit, Plant Etc: $216,179,783 (10.3%)
#     4. 30 Pharmaceutical Products: $135,317,322 (6.5%)
#     5. 23 Food Industry Residues & Waste; Prep Animal Feed: $88,155,449 (4.2%)
#
# === KEY TEMPORAL INSIGHTS ===
# • Peak export period: Nov-24 ($2,863,370,573)
# • Lowest export period: Jul-09 ($1,135,365,550)
